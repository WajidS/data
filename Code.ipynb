# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
#Q3
final.memory_usage(index=True).sum() 
vidsummed = (final[['video']] == 1).sum(axis=1) * 512
print(len([final['photos'].map(lambda d: len(d)) > 0]))


# picsummed = ((final[['photos']] != [])).sum(axis=1)

# %%
#Q1
df10 = pd.read_csv('../input/elon-musk-tweets-2010-2021/2010.csv', on_bad_lines='skip')
df = pd.read_csv('../input/elon-musk-tweets-2010-2021/2011.csv', on_bad_lines='skip')
df0 = pd.read_csv('../input/elon-musk-tweets-2010-2021/2012.csv', on_bad_lines='skip')
df1 = pd.read_csv('../input/elon-musk-tweets-2010-2021/2013.csv', on_bad_lines='skip')
df2 = pd.read_csv('../input/elon-musk-tweets-2010-2021/2014.csv', on_bad_lines='skip')
df3 = pd.read_csv('../input/elon-musk-tweets-2010-2021/2015.csv', on_bad_lines='skip')
df4 = pd.read_csv('../input/elon-musk-tweets-2010-2021/2016.csv', on_bad_lines='skip')
df5 = pd.read_csv('../input/elon-musk-tweets-2010-2021/2017.csv', on_bad_lines='skip')
df6 = pd.read_csv('../input/elon-musk-tweets-2010-2021/2018.csv', on_bad_lines='skip')
df7 = pd.read_csv('../input/elon-musk-tweets-2010-2021/2019.csv', on_bad_lines='skip')
df8 = pd.read_csv('../input/elon-musk-tweets-2010-2021/2020.csv', on_bad_lines='skip')
df9 = pd.read_csv('../input/elon-musk-tweets-2010-2021/2021.csv', on_bad_lines='skip')
final = pd.concat([df,df0,df1,df2,df3,df4,df5,df6,df7,df8,df9,df10], sort=False)
total = final['nlikes'].sum() 
rows,col = final.shape
avg = total / rows
print(rows)
print(avg)

# %%
engage = ((final['nlikes'].sum() + final['nreplies'].sum() + final['nretweets'].sum()) / 0.05) / rows
print(engage)

# %%
#q3
framemem = final.memory_usage(index=True).sum()
vidmem = len(final[final["video"] != 0]) * (1000000)
picmem = len(final[final["photos"] != '[]']) * 290000
memtweet = (framemem +  picmem + vidmem) / rows
print(memtweet)

# %%
#q4
totaldata = memtweet * rows * 2 
print(totaldata)

# %%
#q5
totalviews = engage * rows
yearstomin = 525960 * 11
print(yearstomin)
tweetmin = totalviews / yearstomin
print(tweetmin)

# %%
#q6
accessmin = tweetmin * memtweet
print(accessmin)

# %%
#q7
# I Will be doing the Like function
#calculate on average how many likes a tweet gets within a month by taking total likes and dividing by months within 11 years
likepermonth = final['nlikes'].sum() / (11*12)
#multiply by average amount of memory stored in a tweet because you are modifying the whole tweet 
modified_data_per_like = likepermonth * memtweet
